# %%
import numpy as np
import pandas as pd
import re
import requests
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
from bs4 import BeautifulSoup

# %%
df = pd.read_csv(r"/content/drive/MyDrive/ev_database.csv")
df
# Out:
#                             product_name  \
# 0                 MG MG4 Electric 64 kWh
# 1                     Volvo EX60 P12 AWD
# 2                      BMW iX3 50 xDrive
# 3                        BMW iX xDrive40
# 4             Fiat 500e Hatchback 42 kWh
# ...                                  ...
# 1209     Citroen e-SpaceTourer XS 50 kWh
# 1210     Citroen e-SpaceTourer XL 50 kWh
# 1211             Fiat E-Ulysse L3 50 kWh
# 1212  Porsche Taycan Turbo Cross Turismo
# 1213  Peugeot e-Traveller Compact 50 kWh
#
#                                      Availability             Price  \
# 0           Available to order since October 2022  €103 /km€275 /km
# 1           Available to order since January 2026  €120 /km€275 /km
# 2         Available to order since September 2025  €114 /km€275 /km
# 3      Discontinued (October 2021 - January 2025)  €225 /km€275 /km
# 4          Available to order since November 2020  €128 /km€275 /km
# ...                                           ...               ...
# 1209  Discontinued (November 2020 - October 2021)  €275 /km€275 /km
# 1210  Discontinued (November 2020 - January 2024)  €291 /km€275 /km
# 1211      Discontinued (June 2022 - January 2024)  €317 /km€275 /km
# 1212  Discontinued (January 2023 - February 2024)  €380 /km€275 /km
# 1213   Discontinued (January 2021 - January 2022)  €275 /km€275 /km
#
#      Vechile_range Efficiency   Weight Acceleration Long_distance    battery  \
# 0           360 km  171 Wh/km  1726 kg      7.9 sec        405 km   61.7 kWh
# 1           610 km  184 Wh/km  2405 kg      3.9 sec        742 km  112.0 kWh
# 2           610 km  178 Wh/km  2360 kg      4.9 sec        742 km  108.7 kWh
# 3           360 km  197 Wh/km  2440 kg      6.1 sec        388 km   71.0 kWh
# 4           235 km  159 Wh/km  1365 kg      9.0 sec        261 km   37.3 kWh
# ...            ...        ...      ...          ...           ...        ...
# 1209        185 km  250 Wh/km  1932 kg     12.1 sec        191 km   46.3 kWh
# 1210        180 km  257 Wh/km  1989 kg     12.1 sec        191 km   46.3 kWh
# 1211        180 km  257 Wh/km  1989 kg     12.1 sec        191 km   46.3 kWh
# 1212        425 km  197 Wh/km  2395 kg      3.3 sec        538 km   83.7 kWh
# 1213        185 km  250 Wh/km  1932 kg     12.1 sec        191 km   46.3 kWh
#
#      Fast_Charge  ...  Uk_Price        Driver_Type No.of_Seats Heat_Pump  \
# 0         115 kW  ...   £29,745   Rear Wheel Drive           5         1
# 1         250 kW  ...   £64,860    All Wheel Drive           5         1
# 2         230 kW  ...   £58,755    All Wheel Drive           5         1
# 3         102 kW  ...   £69,905    All Wheel Drive           5         1
# 4          67 kW  ...   £23,995  Front Wheel Drive           4         0
# ...          ...  ...       ...                ...         ...       ...
# 1209       78 kW  ...       NaN  Front Wheel Drive           7         0
# 1210       78 kW  ...   £37,885  Front Wheel Drive           7         1
# 1211       78 kW  ...       NaN  Front Wheel Drive           7         0
# 1212      216 kW  ...  £126,800    All Wheel Drive           5         1
# 1213       78 kW  ...       NaN  Front Wheel Drive           7         0
#
#      Towbar Rating  Bidirectional  Load  Home  Grid
# 0         1    5.0              1     1     1     1
# 1         1    NaN              1     1     1     1
# 2         1    NaN              1     1     1     1
# 3         1    5.0              0     1     1     1
# 4         0    4.0              0     1     1     1
# ...     ...    ...            ...   ...   ...   ...
# 1209      1    NaN              0     1     1     1
# 1210      1    NaN              0     1     1     1
# 1211      1    NaN              0     1     1     1
# 1212      0    NaN              0     1     1     1
# 1213      1    NaN              0     1     1     1
#
# [1214 rows x 24 columns]

# %%
df.shape
# Out:
# (1214, 24)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1214 entries, 0 to 1213
# Data columns (total 24 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   product_name       1214 non-null   object
#  1   Availability       1214 non-null   object
#  2   Price              1214 non-null   object
#  3   Vechile_range      1214 non-null   object
#  4   Efficiency         1214 non-null   object
#  5   Weight             1214 non-null   object
#  6   Acceleration       1214 non-null   object
#  7   Long_distance      1214 non-null   object
#  8   battery            1214 non-null   object
#  9   Fast_Charge        1214 non-null   object
#  10  Towing             1214 non-null   object
#  11  Cargo_vol          1214 non-null   object
#  12  German_Price       1137 non-null   object
#  13  Netherlands_Price  1097 non-null   object
#  14  Uk_Price           884 non-null    object
#  15  Driver_Type        1214 non-null   object
#  16  No.of_Seats        1214 non-null   int64
#  17  Heat_Pump          1214 non-null   int64
#  18  Towbar             1214 non-null   int64
#  19  Rating             728 non-null    float64
#  20  Bidirectional      1214 non-null   int64
#  21  Load               1214 non-null   int64
#  22  Home               1214 non-null   int64
#  23  Grid               1214 non-null   int64
# dtypes: float64(1), int64(7), object(16)
# memory usage: 227.8+ KB

# %%
df.describe()
# Out:
#        No.of_Seats    Heat_Pump       Towbar      Rating  Bidirectional  \
# count  1214.000000  1214.000000  1214.000000  728.000000    1214.000000
# mean      5.219110     0.794893     0.699341    4.813187       0.290774
# std       0.823058     0.403946     0.458734    0.575274       0.454307
# min       2.000000     0.000000     0.000000    0.000000       0.000000
# 25%       5.000000     1.000000     0.000000    5.000000       0.000000
# 50%       5.000000     1.000000     1.000000    5.000000       0.000000
# 75%       5.000000     1.000000     1.000000    5.000000       1.000000
# max       7.000000     1.000000     1.000000    5.000000       1.000000
#
#          Load    Home    Grid
# count  1214.0  1214.0  1214.0
# mean      1.0     1.0     1.0
# std       0.0     0.0     0.0
# min       1.0     1.0     1.0
# 25%       1.0     1.0     1.0
# 50%       1.0     1.0     1.0
# 75%       1.0     1.0     1.0
# max       1.0     1.0     1.0

# %%
df.describe(include="all")
# Out:
#                         product_name                        Availability  \
# count                           1214                                1214
# unique                           860                                 409
# top     Tesla Model 3 Long Range AWD  Available to order since July 2025
# freq                               6                                  42
# mean                             NaN                                 NaN
# std                              NaN                                 NaN
# min                              NaN                                 NaN
# 25%                              NaN                                 NaN
# 50%                              NaN                                 NaN
# 75%                              NaN                                 NaN
# max                              NaN                                 NaN
#
#                    Price Vechile_range Efficiency   Weight Acceleration  \
# count               1214          1214       1214     1214         1214
# unique               266           109        120      534          121
# top     €124 /km€275 /km        350 km  168 Wh/km  2395 kg      9.0 sec
# freq                  22            35         37       10           38
# mean                 NaN           NaN        NaN      NaN          NaN
# std                  NaN           NaN        NaN      NaN          NaN
# min                  NaN           NaN        NaN      NaN          NaN
# 25%                  NaN           NaN        NaN      NaN          NaN
# 50%                  NaN           NaN        NaN      NaN          NaN
# 75%                  NaN           NaN        NaN      NaN          NaN
# max                  NaN           NaN        NaN      NaN          NaN
#
#        Long_distance   battery Fast_Charge  ... Uk_Price      Driver_Type  \
# count           1214      1214        1214  ...      884             1214
# unique           415       194         103  ...      753                3
# top           252 km  77.0 kWh      110 kW  ...  £44,990  All Wheel Drive
# freq              27        65          68  ...        9              487
# mean             NaN       NaN         NaN  ...      NaN              NaN
# std              NaN       NaN         NaN  ...      NaN              NaN
# min              NaN       NaN         NaN  ...      NaN              NaN
# 25%              NaN       NaN         NaN  ...      NaN              NaN
# 50%              NaN       NaN         NaN  ...      NaN              NaN
# 75%              NaN       NaN         NaN  ...      NaN              NaN
# max              NaN       NaN         NaN  ...      NaN              NaN
#
#         No.of_Seats    Heat_Pump       Towbar      Rating  Bidirectional  \
# count   1214.000000  1214.000000  1214.000000  728.000000    1214.000000
# unique          NaN          NaN          NaN         NaN            NaN
# top             NaN          NaN          NaN         NaN            NaN
# freq            NaN          NaN          NaN         NaN            NaN
# mean       5.219110     0.794893     0.699341    4.813187       0.290774
# std        0.823058     0.403946     0.458734    0.575274       0.454307
# min        2.000000     0.000000     0.000000    0.000000       0.000000
# 25%        5.000000     1.000000     0.000000    5.000000       0.000000
# 50%        5.000000     1.000000     1.000000    5.000000       0.000000
# 75%        5.000000     1.000000     1.000000    5.000000       1.000000
# max        7.000000     1.000000     1.000000    5.000000       1.000000
#
#           Load    Home    Grid
# count   1214.0  1214.0  1214.0
# unique     NaN     NaN     NaN
# top        NaN     NaN     NaN
# freq       NaN     NaN     NaN
# mean       1.0     1.0     1.0
# std        0.0     0.0     0.0
# min        1.0     1.0     1.0
# 25%        1.0     1.0     1.0
# 50%        1.0     1.0     1.0
# 75%        1.0     1.0     1.0
# max        1.0     1.0     1.0
#
# [11 rows x 24 columns]

# %%
df.isnull().sum()
# Out:
# product_name           0
# Availability           0
# Price                  0
# Vechile_range          0
# Efficiency             0
# Weight                 0
# Acceleration           0
# Long_distance          0
# battery                0
# Fast_Charge            0
# Towing                 0
# Cargo_vol              0
# German_Price          77
# Netherlands_Price    117
# Uk_Price             330
# Driver_Type            0
# No.of_Seats            0
# Heat_Pump              0
# Towbar                 0
# Rating               486
# Bidirectional          0
# Load                   0
# Home                   0
# Grid                   0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df["Rating"].mode()[0]
# Out:
# np.float64(5.0)

# %%
df["Rating"].fillna(df["Rating"].mode()[0], inplace =True)

# %%
df.isnull().sum()
# Out:
# product_name           0
# Availability           0
# Price                  0
# Vechile_range          0
# Efficiency             0
# Weight                 0
# Acceleration           0
# Long_distance          0
# battery                0
# Fast_Charge            0
# Towing                 0
# Cargo_vol              0
# German_Price          77
# Netherlands_Price    117
# Uk_Price             330
# Driver_Type            0
# No.of_Seats            0
# Heat_Pump              0
# Towbar                 0
# Rating                 0
# Bidirectional          0
# Load                   0
# Home                   0
# Grid                   0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df["Brand"]=df["product_name"].apply(lambda x: re.findall(r"^\w+", x)[0])

# %%
df.head(1)
# Out:
#              product_name                           Availability  \
# 0  MG MG4 Electric 64 kWh  Available to order since October 2022
#
#               Price Vechile_range Efficiency   Weight Acceleration  \
# 0  €103 /km€275 /km        360 km  171 Wh/km  1726 kg      7.9 sec
#
#   Long_distance   battery Fast_Charge  ...       Driver_Type No.of_Seats  \
# 0        405 km  61.7 kWh      115 kW  ...  Rear Wheel Drive           5
#
#   Heat_Pump Towbar Rating Bidirectional  Load  Home  Grid  Brand
# 0         1      1    5.0             1     1     1     1     MG
#
# [1 rows x 25 columns]

# %%
df["Range"]=df["Vechile_range"].apply(lambda x:re.findall(r"[0-9]+", x)[0])

# %%
df.head(1)
# Out:
#              product_name                           Availability  \
# 0  MG MG4 Electric 64 kWh  Available to order since October 2022
#
#               Price Vechile_range Efficiency   Weight Acceleration  \
# 0  €103 /km€275 /km        360 km  171 Wh/km  1726 kg      7.9 sec
#
#   Long_distance   battery Fast_Charge  ... No.of_Seats Heat_Pump Towbar  \
# 0        405 km  61.7 kWh      115 kW  ...           5         1      1
#
#   Rating Bidirectional Load  Home  Grid  Brand  Range
# 0    5.0             1    1     1     1     MG    360
#
# [1 rows x 26 columns]

# %%
df["efficiency"]=df["Efficiency"].apply(lambda x:re.findall(r"[0-9]+", x)[0])

# %%
df.head(1)
# Out:
#              product_name                           Availability  \
# 0  MG MG4 Electric 64 kWh  Available to order since October 2022
#
#               Price Vechile_range Efficiency   Weight Acceleration  \
# 0  €103 /km€275 /km        360 km  171 Wh/km  1726 kg      7.9 sec
#
#   Long_distance   battery Fast_Charge  ... Heat_Pump Towbar Rating  \
# 0        405 km  61.7 kWh      115 kW  ...         1      1    5.0
#
#   Bidirectional Load Home  Grid  Brand  Range  efficiency
# 0             1    1    1     1     MG    360         171
#
# [1 rows x 27 columns]

# %%
df["weight"]=df["Weight"].apply(lambda x:re.findall(r"[0-9]+", x)[0])

# %%
df.head(1)
# Out:
#              product_name                           Availability  \
# 0  MG MG4 Electric 64 kWh  Available to order since October 2022
#
#               Price Vechile_range Efficiency   Weight Acceleration  \
# 0  €103 /km€275 /km        360 km  171 Wh/km  1726 kg      7.9 sec
#
#   Long_distance   battery Fast_Charge  ... Towbar Rating Bidirectional Load  \
# 0        405 km  61.7 kWh      115 kW  ...      1    5.0             1    1
#
#   Home Grid  Brand  Range  efficiency  weight
# 0    1    1     MG    360         171    1726
#
# [1 rows x 28 columns]

# %%
df["speed"]=df["Acceleration"].apply(lambda x:re.findall(r"[.0-9]+", x)[0])

# %%
df.head(1)
# Out:
#              product_name                           Availability  \
# 0  MG MG4 Electric 64 kWh  Available to order since October 2022
#
#               Price Vechile_range Efficiency   Weight Acceleration  \
# 0  €103 /km€275 /km        360 km  171 Wh/km  1726 kg      7.9 sec
#
#   Long_distance   battery Fast_Charge  ... Rating Bidirectional Load Home  \
# 0        405 km  61.7 kWh      115 kW  ...    5.0             1    1    1
#
#   Grid Brand  Range  efficiency  weight  speed
# 0    1    MG    360         171    1726    7.9
#
# [1 rows x 29 columns]

# %%
df["Fast_charge"]=df["Fast_Charge"].apply(lambda x:re.findall(r"[0-9]+", x)[0])

# %%
df.head(1)
# Out:
#              product_name                           Availability  \
# 0  MG MG4 Electric 64 kWh  Available to order since October 2022
#
#               Price Vechile_range Efficiency   Weight Acceleration  \
# 0  €103 /km€275 /km        360 km  171 Wh/km  1726 kg      7.9 sec
#
#   Long_distance   battery Fast_Charge  ... Bidirectional Load Home Grid Brand  \
# 0        405 km  61.7 kWh      115 kW  ...             1    1    1    1    MG
#
#   Range  efficiency  weight  speed  Fast_charge
# 0   360         171    1726    7.9          115
#
# [1 rows x 30 columns]

# %%
df.head(1)
# Out:
#              product_name                           Availability  \
# 0  MG MG4 Electric 64 kWh  Available to order since October 2022
#
#               Price Vechile_range Efficiency   Weight Acceleration  \
# 0  €103 /km€275 /km        360 km  171 Wh/km  1726 kg      7.9 sec
#
#   Long_distance   battery Fast_Charge  ... Bidirectional Load Home Grid Brand  \
# 0        405 km  61.7 kWh      115 kW  ...             1    1    1    1    MG
#
#   Range  efficiency  weight  speed  Fast_charge
# 0   360         171    1726    7.9          115
#
# [1 rows x 30 columns]

# %%
df["distance"]=df["Long_distance"].apply(lambda x:re.findall(r"[0-9]+", x)[0])

# %%
df.head(1)
# Out:
#              product_name                           Availability  \
# 0  MG MG4 Electric 64 kWh  Available to order since October 2022
#
#               Price Vechile_range Efficiency   Weight Acceleration  \
# 0  €103 /km€275 /km        360 km  171 Wh/km  1726 kg      7.9 sec
#
#   Long_distance   battery Fast_Charge  ... Load Home Grid Brand Range  \
# 0        405 km  61.7 kWh      115 kW  ...    1    1    1    MG   360
#
#   efficiency  weight  speed  Fast_charge  distance
# 0        171    1726    7.9          115       405
#
# [1 rows x 31 columns]

# %%
df["cargo_vol"] = df["Cargo_vol"].apply(lambda x: (re.findall(r"[0-9]+", str(x)) or [np.nan])[0] if pd.notna(x) else np.nan)
df["cargo_vol"] = pd.to_numeric(df["cargo_vol"], errors="coerce").astype("Int64")

# %%
df.head(1)
# Out:
#              product_name                           Availability  \
# 0  MG MG4 Electric 64 kWh  Available to order since October 2022
#
#               Price Vechile_range Efficiency   Weight Acceleration  \
# 0  €103 /km€275 /km        360 km  171 Wh/km  1726 kg      7.9 sec
#
#   Long_distance   battery Fast_Charge  ... Home Grid Brand Range efficiency  \
# 0        405 km  61.7 kWh      115 kW  ...    1    1    MG   360        171
#
#   weight  speed  Fast_charge  distance  cargo_vol
# 0   1726    7.9          115       405        363
#
# [1 rows x 32 columns]

# %%
df["Battery"] = df["battery"].apply(lambda x: (re.findall(r"[0-9.]+", str(x)) or [np.nan])[0] if pd.notna(x) else np.nan)
df["Battery"] = pd.to_numeric(df["Battery"], errors="coerce")

# %%
df.head(1)
# Out:
#              product_name                           Availability  \
# 0  MG MG4 Electric 64 kWh  Available to order since October 2022
#
#               Price Vechile_range Efficiency   Weight Acceleration  \
# 0  €103 /km€275 /km        360 km  171 Wh/km  1726 kg      7.9 sec
#
#   Long_distance   battery Fast_Charge  ... Grid Brand Range efficiency weight  \
# 0        405 km  61.7 kWh      115 kW  ...    1    MG   360        171   1726
#
#   speed  Fast_charge  distance  cargo_vol  Battery
# 0   7.9          115       405        363     61.7
#
# [1 rows x 33 columns]

# %%
df['Battery'].unique()
# Out:
# array([ 61.7, 112. , 108.7,  71. ,  37.3,  58. ,  75. ,  85. ,  77. ,
#         60. ,  45.1,  78. ,  91.3,  79. ,  94. ,  65. ,  52. ,  68. ,
#         60.5,  57. ,  64.8,  58.9,  67. ,  86.5,  74. ,  80. ,  65.4,
#         64.7,  43.8, 118. ,  80.7,  73.5,  32. ,  96. ,  82.5,  76. ,
#         36. ,  72. ,  46. ,  87. ,  64. , 108.8,  51. ,  70.5,  62.1,
#         62. ,  59. ,  49. , 117. ,  43.2,  38.3,  76.6,  95. ,  37.9,
#         55. ,  94.9,  60.2,  87.5,  68.3,  91. ,  43.6,  27.5,  65.2,
#        105.2,  71.8,  81.3, 102. ,  50.8,  66.5,  86. ,  96.9,  28.9,
#         40. ,  73. ,  67.1,  81.9,  39. ,  57.4, 106. ,  53.5, 116. ,
#         72.5,  28. , 108. ,  39.2,  50. ,  92.2,  46.3, 109.1,  81.2,
#         30. ,  32.3,  41.2,  49.2,  52.5,  42.5,  90. ,  16.7,  85.4,
#         74.4, 123. ,  24. ,  70. ,  69. ,  67.8,  96.5,  54. , 101.7,
#         69.9,  83.7,  25. ,  94.8, 100. ,  74.3,  61.4,  21.3,  59.8,
#         61.9,  45. ,  29.8,  36.6,  80.8,  88. ,  37. ,  85.5,  28.5,
#         82.7,  98. ,  73.7, 107. ,  93.1,  82.3,  97. ,  48.1,  27.2,
#         55.4,  75.8,  29. ,  90.6,  84. ,  48.4,  89. ,  84.7,  22. ,
#         59.6,  63. ,  31. ,  18.8,  20.5, 108.4, 109. ,  66. ,  80.6,
#         45.4,  65.3,  86.4,  97.2,  19.6, 107.8,  76.5,  83. ,  23.3,
#         95.3,  16. ,  38.5,  78.2,  27. , 108.9,  41. ,  47.1,  98.9,
#         98.6,  48.8,  58.3,  44.9,  48. ,  14.5,  61. , 106.5,  35. ,
#         77.3,  47.8,  81. ,  56. ,  47. ,  72.6,  59.3,  87.7,  83.5,
#         82.2,  92. ,  63.8,  64.3,  48.6])

# %%
df["german_price"] = df["German_Price"].apply(lambda x: re.sub(r"[€,]", "", x) if pd.notna(x) else np.nan)
df["german_price"] = pd.to_numeric(df["german_price"], errors="coerce").astype("Int64")

# %%
df.dtypes
# Out:
# product_name          object
# Availability          object
# Price                 object
# Vechile_range         object
# Efficiency            object
# Weight                object
# Acceleration          object
# Long_distance         object
# battery               object
# Fast_Charge           object
# Towing                object
# Cargo_vol             object
# German_Price          object
# Netherlands_Price     object
# Uk_Price              object
# Driver_Type           object
# No.of_Seats            int64
# Heat_Pump              int64
# Towbar                 int64
# Rating               float64
# Bidirectional          int64
# Load                   int64
# Home                   int64
# Grid                   int64
# Brand                 object
# Range                 object
# efficiency            object
# weight                object
# speed                 object
# Fast_charge           object
# distance              object
# cargo_vol              Int64
# Battery              float64
# german_price           Int64
# dtype: object

# %%
df.head(1)
# Out:
#              product_name                           Availability  \
# 0  MG MG4 Electric 64 kWh  Available to order since October 2022
#
#               Price Vechile_range Efficiency   Weight Acceleration  \
# 0  €103 /km€275 /km        360 km  171 Wh/km  1726 kg      7.9 sec
#
#   Long_distance   battery Fast_Charge  ... Brand Range efficiency weight  \
# 0        405 km  61.7 kWh      115 kW  ...    MG   360        171   1726
#
#   speed Fast_charge  distance  cargo_vol  Battery  german_price
# 0   7.9         115       405        363     61.7         39990
#
# [1 rows x 34 columns]

# %%
df["netherland_price"] = df["Netherlands_Price"].apply(lambda x: re.sub(r"[€*,]", "", x) if pd.notna(x) else np.nan)
df["netherland_price"] = pd.to_numeric(df["netherland_price"], errors="coerce").astype("Int64")

# %%
df.head(1)
# Out:
#              product_name                           Availability  \
# 0  MG MG4 Electric 64 kWh  Available to order since October 2022
#
#               Price Vechile_range Efficiency   Weight Acceleration  \
# 0  €103 /km€275 /km        360 km  171 Wh/km  1726 kg      7.9 sec
#
#   Long_distance   battery Fast_Charge  ... Range efficiency weight speed  \
# 0        405 km  61.7 kWh      115 kW  ...   360        171   1726   7.9
#
#   Fast_charge distance  cargo_vol  Battery  german_price  netherland_price
# 0         115      405        363     61.7         39990             37570
#
# [1 rows x 35 columns]

# %%
df['uk_price']=df["Uk_Price"].apply(lambda x: re.sub(r"[£,]", "", str(x)) if pd.notna(x) else np.nan)
df['uk_price']=pd.to_numeric(df["uk_price"], errors="coerce").astype("Int64")

# %%
df.columns
# Out:
# Index(['product_name', 'Availability', 'Price', 'Vechile_range', 'Efficiency',
#        'Weight', 'Acceleration', 'Long_distance', 'battery', 'Fast_Charge',
#        'Towing', 'Cargo_vol', 'German_Price', 'Netherlands_Price', 'Uk_Price',
#        'Driver_Type', 'No.of_Seats', 'Heat_Pump', 'Towbar', 'Rating',
#        'Bidirectional', 'Load', 'Home', 'Grid', 'Brand', 'Range', 'efficiency',
#        'weight', 'speed', 'Fast_charge', 'distance', 'cargo_vol', 'Battery',
#        'german_price', 'netherland_price', 'uk_price'],
#       dtype='object')

# %%
df.head(5)
# Out:
#                  product_name                                Availability  \
# 0      MG MG4 Electric 64 kWh       Available to order since October 2022
# 1          Volvo EX60 P12 AWD       Available to order since January 2026
# 2           BMW iX3 50 xDrive     Available to order since September 2025
# 3             BMW iX xDrive40  Discontinued (October 2021 - January 2025)
# 4  Fiat 500e Hatchback 42 kWh      Available to order since November 2020
#
#               Price Vechile_range Efficiency   Weight Acceleration  \
# 0  €103 /km€275 /km        360 km  171 Wh/km  1726 kg      7.9 sec
# 1  €120 /km€275 /km        610 km  184 Wh/km  2405 kg      3.9 sec
# 2  €114 /km€275 /km        610 km  178 Wh/km  2360 kg      4.9 sec
# 3  €225 /km€275 /km        360 km  197 Wh/km  2440 kg      6.1 sec
# 4  €128 /km€275 /km        235 km  159 Wh/km  1365 kg      9.0 sec
#
#   Long_distance    battery Fast_Charge  ... efficiency weight speed  \
# 0        405 km   61.7 kWh      115 kW  ...        171   1726   7.9
# 1        742 km  112.0 kWh      250 kW  ...        184   2405   3.9
# 2        742 km  108.7 kWh      230 kW  ...        178   2360   4.9
# 3        388 km   71.0 kWh      102 kW  ...        197   2440   6.1
# 4        261 km   37.3 kWh       67 kW  ...        159   1365   9.0
#
#   Fast_charge distance cargo_vol  Battery  german_price  netherland_price  \
# 0         115      405       363     61.7         39990             37570
# 1         250      742       575    112.0         71990             72995
# 2         230      742       578    108.7         70900             70501
# 3         102      388       500     71.0         77300             84998
# 4          67      261       185     37.3         34990             27999
#
#    uk_price
# 0     29745
# 1     64860
# 2     58755
# 3     69905
# 4     23995
#
# [5 rows x 36 columns]

# %%
df["driver_type"] = df["Driver_Type"].apply(lambda x: " ".join(re.findall(r"[A-Za-z]+", str(x))[:2]))

# %%
df.head(1)
# Out:
#              product_name                           Availability  \
# 0  MG MG4 Electric 64 kWh  Available to order since October 2022
#
#               Price Vechile_range Efficiency   Weight Acceleration  \
# 0  €103 /km€275 /km        360 km  171 Wh/km  1726 kg      7.9 sec
#
#   Long_distance   battery Fast_Charge  ... weight speed Fast_charge distance  \
# 0        405 km  61.7 kWh      115 kW  ...   1726   7.9         115      405
#
#   cargo_vol Battery  german_price  netherland_price  uk_price  driver_type
# 0       363    61.7         39990             37570     29745   Rear Wheel
#
# [1 rows x 37 columns]

# %%
df["price_per_km"] = df["Price"].apply(
    lambda x: (re.findall(r"[0-9.]+", str(x)) or [np.nan])[0] if pd.notna(x) else np.nan
)

df["price_per_km"] = pd.to_numeric(df["price_per_km"], errors="coerce")

# %%
df.head(1)
# Out:
#              product_name                           Availability  \
# 0  MG MG4 Electric 64 kWh  Available to order since October 2022
#
#               Price Vechile_range Efficiency   Weight Acceleration  \
# 0  €103 /km€275 /km        360 km  171 Wh/km  1726 kg      7.9 sec
#
#   Long_distance   battery Fast_Charge  ... speed Fast_charge distance  \
# 0        405 km  61.7 kWh      115 kW  ...   7.9         115      405
#
#   cargo_vol Battery german_price  netherland_price  uk_price  driver_type  \
# 0       363    61.7        39990             37570     29745   Rear Wheel
#
#    price_per_km
# 0           103
#
# [1 rows x 38 columns]

# %%
df["availability_status"] = df["Availability"].apply(
    lambda x: (re.findall(r"Available|Discontinued", str(x)) or [np.nan])[0] if pd.notna(x) else np.nan)

# %%
df.head(1)
# Out:
#              product_name                           Availability  \
# 0  MG MG4 Electric 64 kWh  Available to order since October 2022
#
#               Price Vechile_range Efficiency   Weight Acceleration  \
# 0  €103 /km€275 /km        360 km  171 Wh/km  1726 kg      7.9 sec
#
#   Long_distance   battery Fast_Charge  ... Fast_charge distance cargo_vol  \
# 0        405 km  61.7 kWh      115 kW  ...         115      405       363
#
#   Battery german_price netherland_price  uk_price  driver_type  price_per_km  \
# 0    61.7        39990            37570     29745   Rear Wheel           103
#
#    availability_status
# 0            Available
#
# [1 rows x 39 columns]

# %%
df["towing"] = df["Towing"].apply(lambda x: (re.findall(r"[0-9]+", str(x)) or [np.nan])[0] if pd.notna(x) else np.nan)
df["towing"] = pd.to_numeric(df["towing"], errors="coerce").astype("Int64")

# %%
df.dtypes
# Out:
# product_name            object
# Availability            object
# Price                   object
# Vechile_range           object
# Efficiency              object
# Weight                  object
# Acceleration            object
# Long_distance           object
# battery                 object
# Fast_Charge             object
# Towing                  object
# Cargo_vol               object
# German_Price            object
# Netherlands_Price       object
# Uk_Price                object
# Driver_Type             object
# No.of_Seats              int64
# Heat_Pump                int64
# Towbar                   int64
# Rating                 float64
# Bidirectional            int64
# Load                     int64
# Home                     int64
# Grid                     int64
# Brand                   object
# Range                   object
# efficiency              object
# weight                  object
# speed                   object
# Fast_charge             object
# distance                object
# cargo_vol                Int64
# Battery                float64
# german_price             Int64
# netherland_price         Int64
# uk_price                 Int64
# driver_type             object
# price_per_km             int64
# availability_status     object
# towing                   Int64
# dtype: object

# %%
df.head(1)
# Out:
#              product_name                           Availability  \
# 0  MG MG4 Electric 64 kWh  Available to order since October 2022
#
#               Price Vechile_range Efficiency   Weight Acceleration  \
# 0  €103 /km€275 /km        360 km  171 Wh/km  1726 kg      7.9 sec
#
#   Long_distance   battery Fast_Charge  ... distance cargo_vol Battery  \
# 0        405 km  61.7 kWh      115 kW  ...      405       363    61.7
#
#   german_price netherland_price uk_price  driver_type  price_per_km  \
# 0        39990            37570    29745   Rear Wheel           103
#
#    availability_status  towing
# 0            Available     500
#
# [1 rows x 40 columns]

# %%
df['towing'].value_counts()
# Out:
# towing
# 0       336
# 1000    147
# 750     140
# 1500    113
# 1800     84
# 1600     75
# 2000     59
# 1200     53
# 2250     25
# 500      20
# 2500     16
# 1700     15
# 2400      8
# 2100      8
# 2200      8
# 1400      6
# 1100      5
# 300       4
# 900       4
# 550       4
# 1350      4
# 2300      3
# 1250      3
# 1820      3
# 1300      2
# 350       2
# 975       2
# 1225      2
# 1587      2
# 3000      2
# 1150      1
# 910       1
# 680       1
# 1260      1
# 1090      1
# Name: count, dtype: Int64

# %%
df.T
# Out:
#                                                       0     \
# product_name                        MG MG4 Electric 64 kWh
# Availability         Available to order since October 2022
# Price                                     €103 /km€275 /km
# Vechile_range                                       360 km
# Efficiency                                       171 Wh/km
# Weight                                             1726 kg
# Acceleration                                       7.9 sec
# Long_distance                                       405 km
# battery                                           61.7 kWh
# Fast_Charge                                         115 kW
# Towing                                              500 kg
# Cargo_vol                                            363 L
# German_Price                                       €39,990
# Netherlands_Price                                  €37,570
# Uk_Price                                           £29,745
# Driver_Type                               Rear Wheel Drive
# No.of_Seats                                              5
# Heat_Pump                                                1
# Towbar                                                   1
# Rating                                                 5.0
# Bidirectional                                            1
# Load                                                     1
# Home                                                     1
# Grid                                                     1
# Brand                                                   MG
# Range                                                  360
# efficiency                                             171
# weight                                                1726
# speed                                                  7.9
# Fast_charge                                            115
# distance                                               405
# cargo_vol                                              363
# Battery                                               61.7
# german_price                                         39990
# netherland_price                                     37570
# uk_price                                             29745
# driver_type                                     Rear Wheel
# price_per_km                                           103
# availability_status                              Available
# towing                                                 500
#
#                                                       1     \
# product_name                            Volvo EX60 P12 AWD
# Availability         Available to order since January 2026
# Price                                     €120 /km€275 /km
# Vechile_range                                       610 km
# Efficiency                                       184 Wh/km
# Weight                                             2405 kg
# Acceleration                                       3.9 sec
# Long_distance                                       742 km
# battery                                          112.0 kWh
# Fast_Charge                                         250 kW
# Towing                                             2400 kg
# Cargo_vol                                            575 L
# German_Price                                       €71,990
# Netherlands_Price                                  €72,995
# Uk_Price                                           £64,860
# Driver_Type                                All Wheel Drive
# No.of_Seats                                              5
# Heat_Pump                                                1
# Towbar                                                   1
# Rating                                                 5.0
# Bidirectional                                            1
# Load                                                     1
# Home                                                     1
# Grid                                                     1
# Brand                                                Volvo
# Range                                                  610
# efficiency                                             184
# weight                                                2405
# speed                                                  3.9
# Fast_charge                                            250
# distance                                               742
# cargo_vol                                              575
# Battery                                              112.0
# german_price                                         71990
# netherland_price                                     72995
# uk_price                                             64860
# driver_type                                      All Wheel
# price_per_km                                           120
# availability_status                              Available
# towing                                                2400
#
#                                                         2     \
# product_name                               BMW iX3 50 xDrive
# Availability         Available to order since September 2025
# Price                                       €114 /km€275 /km
# Vechile_range                                         610 km
# Efficiency                                         178 Wh/km
# Weight                                               2360 kg
# Acceleration                                         4.9 sec
# Long_distance                                         742 km
# battery                                            108.7 kWh
# Fast_Charge                                           230 kW
# Towing                                               2000 kg
# Cargo_vol                                              578 L
# German_Price                                         €70,900
# Netherlands_Price                                    €70,501
# Uk_Price                                             £58,755
# Driver_Type                                  All Wheel Drive
# No.of_Seats                                                5
# Heat_Pump                                                  1
# Towbar                                                     1
# Rating                                                   5.0
# Bidirectional                                              1
# Load                                                       1
# Home                                                       1
# Grid                                                       1
# Brand                                                    BMW
# Range                                                    610
# efficiency                                               178
# weight                                                  2360
# speed                                                    4.9
# Fast_charge                                              230
# distance                                                 742
# cargo_vol                                                578
# Battery                                                108.7
# german_price                                           70900
# netherland_price                                       70501
# uk_price                                               58755
# driver_type                                        All Wheel
# price_per_km                                             114
# availability_status                                Available
# towing                                                  2000
#
#                                                            3     \
# product_name                                    BMW iX xDrive40
# Availability         Discontinued (October 2021 - January 2025)
# Price                                          €225 /km€275 /km
# Vechile_range                                            360 km
# Efficiency                                            197 Wh/km
# Weight                                                  2440 kg
# Acceleration                                            6.1 sec
# Long_distance                                            388 km
# battery                                                71.0 kWh
# Fast_Charge                                              102 kW
# Towing                                                  2500 kg
# Cargo_vol                                                 500 L
# German_Price                                            €77,300
# Netherlands_Price                                       €84,998
# Uk_Price                                                £69,905
# Driver_Type                                     All Wheel Drive
# No.of_Seats                                                   5
# Heat_Pump                                                     1
# Towbar                                                        1
# Rating                                                      5.0
# Bidirectional                                                 0
# Load                                                          1
# Home                                                          1
# Grid                                                          1
# Brand                                                       BMW
# Range                                                       360
# efficiency                                                  197
# weight                                                     2440
# speed                                                       6.1
# Fast_charge                                                 102
# distance                                                    388
# cargo_vol                                                   500
# Battery                                                    71.0
# german_price                                              77300
# netherland_price                                          84998
# uk_price                                                  69905
# driver_type                                           All Wheel
# price_per_km                                                225
# availability_status                                Discontinued
# towing                                                     2500
#
#                                                        4     \
# product_name                     Fiat 500e Hatchback 42 kWh
# Availability         Available to order since November 2020
# Price                                      €128 /km€275 /km
# Vechile_range                                        235 km
# Efficiency                                        159 Wh/km
# Weight                                              1365 kg
# Acceleration                                        9.0 sec
# Long_distance                                        261 km
# battery                                            37.3 kWh
# Fast_Charge                                           67 kW
# Towing                                                 0 kg
# Cargo_vol                                             185 L
# German_Price                                        €34,990
# Netherlands_Price                                   €27,999
# Uk_Price                                            £23,995
# Driver_Type                               Front Wheel Drive
# No.of_Seats                                               4
# Heat_Pump                                                 0
# Towbar                                                    0
# Rating                                                  4.0
# Bidirectional                                             0
# Load                                                      1
# Home                                                      1
# Grid                                                      1
# Brand                                                  Fiat
# Range                                                   235
# efficiency                                              159
# weight                                                 1365
# speed                                                   9.0
# Fast_charge                                              67
# distance                                                261
# cargo_vol                                               185
# Battery                                                37.3
# german_price                                          34990
# netherland_price                                      27999
# uk_price                                              23995
# driver_type                                     Front Wheel
# price_per_km                                            128
# availability_status                               Available
# towing                                                    0
#
#                                                         5     \
# product_name                      CUPRA Born 150 kW - 58 kWh
# Availability         Discontinued (October 2021 - July 2024)
# Price                                       €110 /km€275 /km
# Vechile_range                                         350 km
# Efficiency                                         166 Wh/km
# Weight                                               1811 kg
# Acceleration                                         7.3 sec
# Long_distance                                         375 km
# battery                                             58.0 kWh
# Fast_Charge                                            82 kW
# Towing                                                  0 kg
# Cargo_vol                                              385 L
# German_Price                                         €39,370
# Netherlands_Price                                    €36,939
# Uk_Price                                             £34,125
# Driver_Type                                 Rear Wheel Drive
# No.of_Seats                                                5
# Heat_Pump                                                  1
# Towbar                                                     0
# Rating                                                   5.0
# Bidirectional                                              0
# Load                                                       1
# Home                                                       1
# Grid                                                       1
# Brand                                                  CUPRA
# Range                                                    350
# efficiency                                               166
# weight                                                  1811
# speed                                                    7.3
# Fast_charge                                               82
# distance                                                 375
# cargo_vol                                                385
# Battery                                                 58.0
# german_price                                           39370
# netherland_price                                       36939
# uk_price                                               34125
# driver_type                                       Rear Wheel
# price_per_km                                             110
# availability_status                             Discontinued
# towing                                                     0
#
#                                                             6     \
# product_name                        Tesla Model Y Long Range AWD
# Availability         Discontinued (February 2025 - October 2025)
# Price                                           €122 /km€275 /km
# Vechile_range                                             455 km
# Efficiency                                             165 Wh/km
# Weight                                                   2072 kg
# Acceleration                                             4.8 sec
# Long_distance                                             535 km
# battery                                                 75.0 kWh
# Fast_Charge                                               124 kW
# Towing                                                   1600 kg
# Cargo_vol                                                  971 L
# German_Price                                             €52,990
# Netherlands_Price                                        €53,990
# Uk_Price                                                 £51,990
# Driver_Type                                      All Wheel Drive
# No.of_Seats                                                    5
# Heat_Pump                                                      1
# Towbar                                                         1
# Rating                                                       5.0
# Bidirectional                                                  0
# Load                                                           1
# Home                                                           1
# Grid                                                           1
# Brand                                                      Tesla
# Range                                                        455
# efficiency                                                   165
# weight                                                      2072
# speed                                                        4.8
# Fast_charge                                                  124
# distance                                                     535
# cargo_vol                                                    971
# Battery                                                     75.0
# german_price                                               52990
# netherland_price                                           53990
# uk_price                                                   51990
# driver_type                                            All Wheel
# price_per_km                                                 122
# availability_status                                 Discontinued
# towing                                                      1600
#
#                                                   7     \
# product_name                    Mercedes-Benz CLA 250+
# Availability         Available to order since May 2025
# Price                                  €92 /km€275 /km
# Vechile_range                                   585 km
# Efficiency                                   145 Wh/km
# Weight                                         2055 kg
# Acceleration                                   6.7 sec
# Long_distance                                   763 km
# battery                                       85.0 kWh
# Fast_Charge                                     235 kW
# Towing                                         1500 kg
# Cargo_vol                                        506 L
# German_Price                                   €55,859
# Netherlands_Price                              €53,554
# Uk_Price                                       £45,615
# Driver_Type                           Rear Wheel Drive
# No.of_Seats                                          5
# Heat_Pump                                            1
# Towbar                                               1
# Rating                                             5.0
# Bidirectional                                        1
# Load                                                 1
# Home                                                 1
# Grid                                                 1
# Brand                                         Mercedes
# Range                                              585
# efficiency                                         145
# weight                                            2055
# speed                                              6.7
# Fast_charge                                        235
# distance                                           763
# cargo_vol                                          506
# Battery                                           85.0
# german_price                                     55859
# netherland_price                                 53554
# uk_price                                         45615
# driver_type                                 Rear Wheel
# price_per_km                                        92
# availability_status                          Available
# towing                                            1500
#
#                                                              8     \
# product_name                         Tesla Model Y Long Range AWD
# Availability         Discontinued (February 2022 - February 2025)
# Price                                            €126 /km€275 /km
# Vechile_range                                              445 km
# Efficiency                                              169 Wh/km
# Weight                                                    2054 kg
# Acceleration                                              5.0 sec
# Long_distance                                              524 km
# battery                                                  75.0 kWh
# Fast_Charge                                                124 kW
# Towing                                                    1600 kg
# Cargo_vol                                                   971 L
# German_Price                                              €55,970
# Netherlands_Price                                         €52,990
# Uk_Price                                                  £51,990
# Driver_Type                                       All Wheel Drive
# No.of_Seats                                                     7
# Heat_Pump                                                       1
# Towbar                                                          1
# Rating                                                        5.0
# Bidirectional                                                   0
# Load                                                            1
# Home                                                            1
# Grid                                                            1
# Brand                                                       Tesla
# Range                                                         445
# efficiency                                                    169
# weight                                                       2054
# speed                                                         5.0
# Fast_charge                                                   124
# distance                                                      524
# cargo_vol                                                     971
# Battery                                                      75.0
# german_price                                                55970
# netherland_price                                            52990
# uk_price                                                    51990
# driver_type                                             All Wheel
# price_per_km                                                  126
# availability_status                                  Discontinued
# towing                                                       1600
#
#                                                       9     ...  \
# product_name                    CUPRA Born 170 kW - 77 kWh  ...
# Availability         Discontinued (March 2022 - July 2024)  ...
# Price                                     €103 /km€275 /km  ...
# Vechile_range                                       450 km  ...
# Efficiency                                       171 Wh/km  ...
# Weight                                             1946 kg  ...
# Acceleration                                       7.0 sec  ...
# Long_distance                                       488 km  ...
# battery                                           77.0 kWh  ...
# Fast_Charge                                         115 kW  ...
# Towing                                                0 kg  ...
# Cargo_vol                                            385 L  ...
# German_Price                                       €46,450  ...
# Netherlands_Price                                  €46,989  ...
# Uk_Price                                           £39,625  ...
# Driver_Type                               Rear Wheel Drive  ...
# No.of_Seats                                              4  ...
# Heat_Pump                                                1  ...
# Towbar                                                   0  ...
# Rating                                                 5.0  ...
# Bidirectional                                            1  ...
# Load                                                     1  ...
# Home                                                     1  ...
# Grid                                                     1  ...
# Brand                                                CUPRA  ...
# Range                                                  450  ...
# efficiency                                             171  ...
# weight                                                1946  ...
# speed                                                  7.0  ...
# Fast_charge                                            115  ...
# distance                                               488  ...
# cargo_vol                                              385  ...
# Battery                                               77.0  ...
# german_price                                         46450  ...
# netherland_price                                     46989  ...
# uk_price                                             39625  ...
# driver_type                                     Rear Wheel  ...
# price_per_km                                           103  ...
# availability_status                           Discontinued  ...
# towing                                                   0  ...
#
#                                                              1204  \
# product_name                      Ford e-Tourneo Custom L1 210 kW
# Availability         Discontinued (November 2023 - December 2025)
# Price                                            €322 /km€275 /km
# Vechile_range                                              235 km
# Efficiency                                              272 Wh/km
# Weight                                                    2557 kg
# Acceleration                                              8.0 sec
# Long_distance                                              245 km
# battery                                                  64.0 kWh
# Fast_Charge                                                105 kW
# Towing                                                    2000 kg
# Cargo_vol                                                   672 L
# German_Price                                              €75,565
# Netherlands_Price                                             NaN
# Uk_Price                                                      NaN
# Driver_Type                                      Rear Wheel Drive
# No.of_Seats                                                     7
# Heat_Pump                                                       1
# Towbar                                                          1
# Rating                                                        5.0
# Bidirectional                                                   0
# Load                                                            1
# Home                                                            1
# Grid                                                            1
# Brand                                                        Ford
# Range                                                         235
# efficiency                                                    272
# weight                                                       2557
# speed                                                         8.0
# Fast_charge                                                   105
# distance                                                      245
# cargo_vol                                                     672
# Battery                                                      64.0
# german_price                                                75565
# netherland_price                                             <NA>
# uk_price                                                     <NA>
# driver_type                                            Rear Wheel
# price_per_km                                                  322
# availability_status                                  Discontinued
# towing                                                       2000
#
#                                                          1205  \
# product_name                   Toyota Proace Shuttle M 50 kWh
# Availability         Discontinued (June 2021 - November 2023)
# Price                                        €318 /km€275 /km
# Vechile_range                                          185 km
# Efficiency                                          250 Wh/km
# Weight                                                1969 kg
# Acceleration                                         12.1 sec
# Long_distance                                          198 km
# battery                                              46.3 kWh
# Fast_Charge                                             78 kW
# Towing                                                1000 kg
# Cargo_vol                                               550 L
# German_Price                                              NaN
# Netherlands_Price                                     €58,895
# Uk_Price                                                  NaN
# Driver_Type                                 Front Wheel Drive
# No.of_Seats                                                 7
# Heat_Pump                                                   1
# Towbar                                                      1
# Rating                                                    5.0
# Bidirectional                                               0
# Load                                                        1
# Home                                                        1
# Grid                                                        1
# Brand                                                  Toyota
# Range                                                     185
# efficiency                                                250
# weight                                                   1969
# speed                                                    12.1
# Fast_charge                                                78
# distance                                                  198
# cargo_vol                                                 550
# Battery                                                  46.3
# german_price                                             <NA>
# netherland_price                                        58895
# uk_price                                                 <NA>
# driver_type                                       Front Wheel
# price_per_km                                              318
# availability_status                              Discontinued
# towing                                                   1000
#
#                                                           1206  \
# product_name              Porsche Taycan 4S Plus Sport Turismo
# Availability         Discontinued (March 2022 - February 2024)
# Price                                         €277 /km€275 /km
# Vechile_range                                           430 km
# Efficiency                                           195 Wh/km
# Weight                                                 2325 kg
# Acceleration                                           4.0 sec
# Long_distance                                           546 km
# battery                                               83.7 kWh
# Fast_Charge                                             216 kW
# Towing                                                    0 kg
# Cargo_vol                                                530 L
# German_Price                                          €120,081
# Netherlands_Price                                     €127,294
# Uk_Price                                               £95,996
# Driver_Type                                    All Wheel Drive
# No.of_Seats                                                  5
# Heat_Pump                                                    1
# Towbar                                                       0
# Rating                                                     5.0
# Bidirectional                                                0
# Load                                                         1
# Home                                                         1
# Grid                                                         1
# Brand                                                  Porsche
# Range                                                      430
# efficiency                                                 195
# weight                                                    2325
# speed                                                      4.0
# Fast_charge                                                216
# distance                                                   546
# cargo_vol                                                  530
# Battery                                                   83.7
# german_price                                            120081
# netherland_price                                        127294
# uk_price                                                 95996
# driver_type                                          All Wheel
# price_per_km                                               277
# availability_status                               Discontinued
# towing                                                       0
#
#                                                       1207  \
# product_name                Opel Zafira Electric XL 50 kWh
# Availability         Available to order since January 2024
# Price                                     €274 /km€275 /km
# Vechile_range                                       180 km
# Efficiency                                       257 Wh/km
# Weight                                             2056 kg
# Acceleration                                      13.3 sec
# Long_distance                                       191 km
# battery                                           46.3 kWh
# Fast_Charge                                          78 kW
# Towing                                             1000 kg
# Cargo_vol                                            989 L
# German_Price                                       €48,550
# Netherlands_Price                                  €49,963
# Uk_Price                                               NaN
# Driver_Type                              Front Wheel Drive
# No.of_Seats                                              7
# Heat_Pump                                                0
# Towbar                                                   1
# Rating                                                 5.0
# Bidirectional                                            0
# Load                                                     1
# Home                                                     1
# Grid                                                     1
# Brand                                                 Opel
# Range                                                  180
# efficiency                                             257
# weight                                                2056
# speed                                                 13.3
# Fast_charge                                             78
# distance                                               191
# cargo_vol                                              989
# Battery                                               46.3
# german_price                                         48550
# netherland_price                                     49963
# uk_price                                              <NA>
# driver_type                                    Front Wheel
# price_per_km                                           274
# availability_status                              Available
# towing                                                1000
#
#                                                            1208  \
# product_name                       Opel Vivaro-e Combi S 50 kWh
# Availability         Discontinued (October 2020 - October 2021)
# Price                                          €268 /km€275 /km
# Vechile_range                                            185 km
# Efficiency                                            250 Wh/km
# Weight                                                  1932 kg
# Acceleration                                           12.1 sec
# Long_distance                                            191 km
# battery                                                46.3 kWh
# Fast_Charge                                               78 kW
# Towing                                                  1000 kg
# Cargo_vol                                                 140 L
# German_Price                                            €49,623
# Netherlands_Price                                           NaN
# Uk_Price                                                    NaN
# Driver_Type                                   Front Wheel Drive
# No.of_Seats                                                   7
# Heat_Pump                                                     0
# Towbar                                                        1
# Rating                                                      5.0
# Bidirectional                                                 0
# Load                                                          1
# Home                                                          1
# Grid                                                          1
# Brand                                                      Opel
# Range                                                       185
# efficiency                                                  250
# weight                                                     1932
# speed                                                      12.1
# Fast_charge                                                  78
# distance                                                    191
# cargo_vol                                                   140
# Battery                                                    46.3
# german_price                                              49623
# netherland_price                                           <NA>
# uk_price                                                   <NA>
# driver_type                                         Front Wheel
# price_per_km                                                268
# availability_status                                Discontinued
# towing                                                     1000
#
#                                                             1209  \
# product_name                     Citroen e-SpaceTourer XS 50 kWh
# Availability         Discontinued (November 2020 - October 2021)
# Price                                           €275 /km€275 /km
# Vechile_range                                             185 km
# Efficiency                                             250 Wh/km
# Weight                                                   1932 kg
# Acceleration                                            12.1 sec
# Long_distance                                             191 km
# battery                                                 46.3 kWh
# Fast_Charge                                                78 kW
# Towing                                                   1000 kg
# Cargo_vol                                                  140 L
# German_Price                                             €50,880
# Netherlands_Price                                            NaN
# Uk_Price                                                     NaN
# Driver_Type                                    Front Wheel Drive
# No.of_Seats                                                    7
# Heat_Pump                                                      0
# Towbar                                                         1
# Rating                                                       5.0
# Bidirectional                                                  0
# Load                                                           1
# Home                                                           1
# Grid                                                           1
# Brand                                                    Citroen
# Range                                                        185
# efficiency                                                   250
# weight                                                      1932
# speed                                                       12.1
# Fast_charge                                                   78
# distance                                                     191
# cargo_vol                                                    140
# Battery                                                     46.3
# german_price                                               50880
# netherland_price                                            <NA>
# uk_price                                                    <NA>
# driver_type                                          Front Wheel
# price_per_km                                                 275
# availability_status                                 Discontinued
# towing                                                      1000
#
#                                                             1210  \
# product_name                     Citroen e-SpaceTourer XL 50 kWh
# Availability         Discontinued (November 2020 - January 2024)
# Price                                           €291 /km€275 /km
# Vechile_range                                             180 km
# Efficiency                                             257 Wh/km
# Weight                                                   1989 kg
# Acceleration                                            12.1 sec
# Long_distance                                             191 km
# battery                                                 46.3 kWh
# Fast_Charge                                                78 kW
# Towing                                                   1000 kg
# Cargo_vol                                                  912 L
# German_Price                                             €54,430
# Netherlands_Price                                        €59,019
# Uk_Price                                                 £37,885
# Driver_Type                                    Front Wheel Drive
# No.of_Seats                                                    7
# Heat_Pump                                                      1
# Towbar                                                         1
# Rating                                                       5.0
# Bidirectional                                                  0
# Load                                                           1
# Home                                                           1
# Grid                                                           1
# Brand                                                    Citroen
# Range                                                        180
# efficiency                                                   257
# weight                                                      1989
# speed                                                       12.1
# Fast_charge                                                   78
# distance                                                     191
# cargo_vol                                                    912
# Battery                                                     46.3
# german_price                                               54430
# netherland_price                                           59019
# uk_price                                                   37885
# driver_type                                          Front Wheel
# price_per_km                                                 291
# availability_status                                 Discontinued
# towing                                                      1000
#
#                                                         1211  \
# product_name                         Fiat E-Ulysse L3 50 kWh
# Availability         Discontinued (June 2022 - January 2024)
# Price                                       €317 /km€275 /km
# Vechile_range                                         180 km
# Efficiency                                         257 Wh/km
# Weight                                               1989 kg
# Acceleration                                        12.1 sec
# Long_distance                                         191 km
# battery                                             46.3 kWh
# Fast_Charge                                            78 kW
# Towing                                               1000 kg
# Cargo_vol                                              800 L
# German_Price                                         €56,990
# Netherlands_Price                                        NaN
# Uk_Price                                                 NaN
# Driver_Type                                Front Wheel Drive
# No.of_Seats                                                7
# Heat_Pump                                                  0
# Towbar                                                     1
# Rating                                                   5.0
# Bidirectional                                              0
# Load                                                       1
# Home                                                       1
# Grid                                                       1
# Brand                                                   Fiat
# Range                                                    180
# efficiency                                               257
# weight                                                  1989
# speed                                                   12.1
# Fast_charge                                               78
# distance                                                 191
# cargo_vol                                                800
# Battery                                                 46.3
# german_price                                           56990
# netherland_price                                        <NA>
# uk_price                                                <NA>
# driver_type                                      Front Wheel
# price_per_km                                             317
# availability_status                             Discontinued
# towing                                                  1000
#
#                                                             1212  \
# product_name                  Porsche Taycan Turbo Cross Turismo
# Availability         Discontinued (January 2023 - February 2024)
# Price                                           €380 /km€275 /km
# Vechile_range                                             425 km
# Efficiency                                             197 Wh/km
# Weight                                                   2395 kg
# Acceleration                                             3.3 sec
# Long_distance                                             538 km
# battery                                                 83.7 kWh
# Fast_Charge                                               216 kW
# Towing                                                      0 kg
# Cargo_vol                                                  489 L
# German_Price                                            €165,848
# Netherlands_Price                                       €173,264
# Uk_Price                                                £126,800
# Driver_Type                                      All Wheel Drive
# No.of_Seats                                                    5
# Heat_Pump                                                      1
# Towbar                                                         0
# Rating                                                       5.0
# Bidirectional                                                  0
# Load                                                           1
# Home                                                           1
# Grid                                                           1
# Brand                                                    Porsche
# Range                                                        425
# efficiency                                                   197
# weight                                                      2395
# speed                                                        3.3
# Fast_charge                                                  216
# distance                                                     538
# cargo_vol                                                    489
# Battery                                                     83.7
# german_price                                              165848
# netherland_price                                          173264
# uk_price                                                  126800
# driver_type                                            All Wheel
# price_per_km                                                 380
# availability_status                                 Discontinued
# towing                                                         0
#
#                                                            1213
# product_name                 Peugeot e-Traveller Compact 50 kWh
# Availability         Discontinued (January 2021 - January 2022)
# Price                                          €275 /km€275 /km
# Vechile_range                                            185 km
# Efficiency                                            250 Wh/km
# Weight                                                  1932 kg
# Acceleration                                           12.1 sec
# Long_distance                                            191 km
# battery                                                46.3 kWh
# Fast_Charge                                               78 kW
# Towing                                                  1000 kg
# Cargo_vol                                               unknown
# German_Price                                            €50,880
# Netherlands_Price                                           NaN
# Uk_Price                                                    NaN
# Driver_Type                                   Front Wheel Drive
# No.of_Seats                                                   7
# Heat_Pump                                                     0
# Towbar                                                        1
# Rating                                                      5.0
# Bidirectional                                                 0
# Load                                                          1
# Home                                                          1
# Grid                                                          1
# Brand                                                   Peugeot
# Range                                                       185
# efficiency                                                  250
# weight                                                     1932
# speed                                                      12.1
# Fast_charge                                                  78
# distance                                                    191
# cargo_vol                                                  <NA>
# Battery                                                    46.3
# german_price                                              50880
# netherland_price                                           <NA>
# uk_price                                                   <NA>
# driver_type                                         Front Wheel
# price_per_km                                                275
# availability_status                                Discontinued
# towing                                                     1000
#
# [40 rows x 1214 columns]

# %%
df.columns
# Out:
# Index(['product_name', 'Availability', 'Price', 'Vechile_range', 'Efficiency',
#        'Weight', 'Acceleration', 'Long_distance', 'battery', 'Fast_Charge',
#        'Towing', 'Cargo_vol', 'German_Price', 'Netherlands_Price', 'Uk_Price',
#        'Driver_Type', 'No.of_Seats', 'Heat_Pump', 'Towbar', 'Rating',
#        'Bidirectional', 'Load', 'Home', 'Grid', 'Brand', 'Range', 'efficiency',
#        'weight', 'speed', 'Fast_charge', 'distance', 'cargo_vol', 'Battery',
#        'german_price', 'netherland_price', 'uk_price', 'driver_type',
#        'price_per_km', 'availability_status', 'towing'],
#       dtype='object')

# %%
df.drop(columns = ['product_name', 'Availability', 'Price', 'Vechile_range', 'Efficiency', 'Weight', 'Acceleration',
       'Long_distance', 'battery', 'Fast_Charge', 'Towing', 'Cargo_vol',
       'German_Price', 'Netherlands_Price', 'Uk_Price', 'Driver_Type'], inplace = True)

# %%
df
# Out:
#       No.of_Seats  Heat_Pump  Towbar  Rating  Bidirectional  Load  Home  Grid  \
# 0               5          1       1     5.0              1     1     1     1
# 1               5          1       1     5.0              1     1     1     1
# 2               5          1       1     5.0              1     1     1     1
# 3               5          1       1     5.0              0     1     1     1
# 4               4          0       0     4.0              0     1     1     1
# ...           ...        ...     ...     ...            ...   ...   ...   ...
# 1209            7          0       1     5.0              0     1     1     1
# 1210            7          1       1     5.0              0     1     1     1
# 1211            7          0       1     5.0              0     1     1     1
# 1212            5          1       0     5.0              0     1     1     1
# 1213            7          0       1     5.0              0     1     1     1
#
#         Brand Range  ... distance cargo_vol Battery german_price  \
# 0          MG   360  ...      405       363    61.7        39990
# 1       Volvo   610  ...      742       575   112.0        71990
# 2         BMW   610  ...      742       578   108.7        70900
# 3         BMW   360  ...      388       500    71.0        77300
# 4        Fiat   235  ...      261       185    37.3        34990
# ...       ...   ...  ...      ...       ...     ...          ...
# 1209  Citroen   185  ...      191       140    46.3        50880
# 1210  Citroen   180  ...      191       912    46.3        54430
# 1211     Fiat   180  ...      191       800    46.3        56990
# 1212  Porsche   425  ...      538       489    83.7       165848
# 1213  Peugeot   185  ...      191      <NA>    46.3        50880
#
#      netherland_price  uk_price  driver_type  price_per_km  \
# 0               37570     29745   Rear Wheel           103
# 1               72995     64860    All Wheel           120
# 2               70501     58755    All Wheel           114
# 3               84998     69905    All Wheel           225
# 4               27999     23995  Front Wheel           128
# ...               ...       ...          ...           ...
# 1209             <NA>      <NA>  Front Wheel           275
# 1210            59019     37885  Front Wheel           291
# 1211             <NA>      <NA>  Front Wheel           317
# 1212           173264    126800    All Wheel           380
# 1213             <NA>      <NA>  Front Wheel           275
#
#       availability_status  towing
# 0               Available     500
# 1               Available    2400
# 2               Available    2000
# 3            Discontinued    2500
# 4               Available       0
# ...                   ...     ...
# 1209         Discontinued    1000
# 1210         Discontinued    1000
# 1211         Discontinued    1000
# 1212         Discontinued       0
# 1213         Discontinued    1000
#
# [1214 rows x 24 columns]

# %%
df.isnull().sum()
# Out:
# No.of_Seats              0
# Heat_Pump                0
# Towbar                   0
# Rating                   0
# Bidirectional            0
# Load                     0
# Home                     0
# Grid                     0
# Brand                    0
# Range                    0
# efficiency               0
# weight                   0
# speed                    0
# Fast_charge              0
# distance                 0
# cargo_vol               27
# Battery                  0
# german_price            81
# netherland_price       117
# uk_price               342
# driver_type              0
# price_per_km             0
# availability_status      0
# towing                  54
# dtype: int64

# %%
df["towing"].median()
# Out:
# np.float64(1000.0)

# %%
df["towing"] = df["towing"].fillna(df["towing"].median()).astype("int64")

# %%
df["cargo_vol"].median()
# Out:
# np.float64(510.0)

# %%
df["cargo_vol"] = df["cargo_vol"].fillna(df["cargo_vol"].median()).astype("int64")

# %%
df.isnull().sum()
# Out:
# No.of_Seats              0
# Heat_Pump                0
# Towbar                   0
# Rating                   0
# Bidirectional            0
# Load                     0
# Home                     0
# Grid                     0
# Brand                    0
# Range                    0
# efficiency               0
# weight                   0
# speed                    0
# Fast_charge              0
# distance                 0
# cargo_vol                0
# Battery                  0
# german_price            81
# netherland_price       117
# uk_price               342
# driver_type              0
# price_per_km             0
# availability_status      0
# towing                   0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df = df[
    ['Brand', 'price_per_km', 'availability_status', 'Range', 'efficiency',
       'weight', 'speed', 'Fast_charge', 'distance', 'cargo_vol', 'Battery',
       'german_price', 'netherland_price', 'uk_price', 'towing','driver_type', 'No.of_Seats', 'Heat_Pump', 'Towbar', 'Rating',
       'Bidirectional', 'Load', 'Home', 'Grid']
]

# %%
df['german_price']
# Out:
# 0        39990
# 1        71990
# 2        70900
# 3        77300
# 4        34990
#          ...
# 1209     50880
# 1210     54430
# 1211     56990
# 1212    165848
# 1213     50880
# Name: german_price, Length: 1214, dtype: Int64

# %%
df.isnull().sum()
# Out:
# Brand                    0
# price_per_km             0
# availability_status      0
# Range                    0
# efficiency               0
# weight                   0
# speed                    0
# Fast_charge              0
# distance                 0
# cargo_vol                0
# Battery                  0
# german_price            81
# netherland_price       117
# uk_price               342
# towing                   0
# driver_type              0
# No.of_Seats              0
# Heat_Pump                0
# Towbar                   0
# Rating                   0
# Bidirectional            0
# Load                     0
# Home                     0
# Grid                     0
# dtype: int64

# %%
df['german_price'].median()
# Out:
# np.float64(55400.0)

# %%
df['netherland_price'].median()
# Out:
# np.float64(54990.0)

# %%
df['uk_price'].median()
# Out:
# np.float64(49825.0)

# %%
df['german_price'].fillna(df['german_price'].median(),inplace=True)

# %%
df['netherland_price'].fillna(df['netherland_price'].median(),inplace=True)

# %%
df['uk_price'].fillna(df['uk_price'].median(),inplace=True)

# %%
df.isna().sum()
# Out:
# Brand                  0
# price_per_km           0
# availability_status    0
# Range                  0
# efficiency             0
# weight                 0
# speed                  0
# Fast_charge            0
# distance               0
# cargo_vol              0
# Battery                0
# german_price           0
# netherland_price       0
# uk_price               0
# towing                 0
# driver_type            0
# No.of_Seats            0
# Heat_Pump              0
# Towbar                 0
# Rating                 0
# Bidirectional          0
# Load                   0
# Home                   0
# Grid                   0
# dtype: int64

# %%
df.to_csv("ev_database_cleaned.csv", index=False)

# %%
df = pd.read_csv("ev_database_cleaned.csv")

# %%
df
# Out:
#         Brand  price_per_km availability_status  Range  efficiency  weight  \
# 0          MG           103           Available    360         171    1726
# 1       Volvo           120           Available    610         184    2405
# 2         BMW           114           Available    610         178    2360
# 3         BMW           225        Discontinued    360         197    2440
# 4        Fiat           128           Available    235         159    1365
# ...       ...           ...                 ...    ...         ...     ...
# 1209  Citroen           275        Discontinued    185         250    1932
# 1210  Citroen           291        Discontinued    180         257    1989
# 1211     Fiat           317        Discontinued    180         257    1989
# 1212  Porsche           380        Discontinued    425         197    2395
# 1213  Peugeot           275        Discontinued    185         250    1932
#
#       speed  Fast_charge  distance  cargo_vol  ...  towing  driver_type  \
# 0       7.9          115       405        363  ...     500   Rear Wheel
# 1       3.9          250       742        575  ...    2400    All Wheel
# 2       4.9          230       742        578  ...    2000    All Wheel
# 3       6.1          102       388        500  ...    2500    All Wheel
# 4       9.0           67       261        185  ...       0  Front Wheel
# ...     ...          ...       ...        ...  ...     ...          ...
# 1209   12.1           78       191        140  ...    1000  Front Wheel
# 1210   12.1           78       191        912  ...    1000  Front Wheel
# 1211   12.1           78       191        800  ...    1000  Front Wheel
# 1212    3.3          216       538        489  ...       0    All Wheel
# 1213   12.1           78       191        510  ...    1000  Front Wheel
#
#       No.of_Seats  Heat_Pump  Towbar Rating  Bidirectional  Load  Home  Grid
# 0               5          1       1    5.0              1     1     1     1
# 1               5          1       1    5.0              1     1     1     1
# 2               5          1       1    5.0              1     1     1     1
# 3               5          1       1    5.0              0     1     1     1
# 4               4          0       0    4.0              0     1     1     1
# ...           ...        ...     ...    ...            ...   ...   ...   ...
# 1209            7          0       1    5.0              0     1     1     1
# 1210            7          1       1    5.0              0     1     1     1
# 1211            7          0       1    5.0              0     1     1     1
# 1212            5          1       0    5.0              0     1     1     1
# 1213            7          0       1    5.0              0     1     1     1
#
# [1214 rows x 24 columns]

# %%
df.isnull().sum()
# Out:
# Brand                  0
# price_per_km           0
# availability_status    0
# Range                  0
# efficiency             0
# weight                 0
# speed                  0
# Fast_charge            0
# distance               0
# cargo_vol              0
# Battery                0
# german_price           0
# netherland_price       0
# uk_price               0
# towing                 0
# driver_type            0
# No.of_Seats            0
# Heat_Pump              0
# Towbar                 0
# Rating                 0
# Bidirectional          0
# Load                   0
# Home                   0
# Grid                   0
# dtype: int64
